# %%
import glob
import os
import pandas as pd
from io import StringIO
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### RNA-seq short-read sequencing data

# %%
x = [1209739373,
1391948738,
1484437130,
1566592547,
1642977079,
1693132573,
1736475901,
1772189757,
1808574091,
1844187035,
1872620001,
1917409580,
1939294188]

# %%
plt.plot(x)
plt.ylabel('distinct k-mers')
plt.xlabel('\propto k-mers in the input data')
# Out:
# Text(0.5,0,'\\propto k-mers in the input data')
